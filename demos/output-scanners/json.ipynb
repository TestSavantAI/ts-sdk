# %%
from testsavant.guard import InputGuard, OutputGuard
from testsavant.guard.output_scanners import JSON
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
guard = OutputGuard()
json_scanner = JSON(
    tag="default",
    repair=True
    )
guard.add_scanner(json_scanner)

# %%
correct_json = """
[{"leo":"aman"}, {"my":"certain}] json
"""

guard.scan(None, correct_json).sanitized_output
# Out:
# '\n[{"leo":"aman"}, {"my": "certain"}] json\n'
