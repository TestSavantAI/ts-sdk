# %%
from testsavant.guard import InputGuard, OutputGuard
from testsavant.guard.output_scanners import JSON
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
guard = OutputGuard()

json_scanner = JSON(
    tag="default",
    repair=True,
    required_elements=["name", "age", "city"]
    )

guard.add_scanner(json_scanner)

# %%
correct_json = """
[{"name": "John Doe", "age": 30, "city": "New York"}, {"name": "Jane Smith", "age": 25, "city": "Los Angeles"] some extra text that is not valid JSON
"""

guard.scan(None, correct_json).sanitized_output
# Out:
# '\n[{"name": "John Doe", "age": 30, "city": "New York"}, {"name": "Jane Smith", "age": 25, "city": "Los Angeles"}]'

# %%
guard.scan(None, correct_json).is_valid
# Out:
# True
