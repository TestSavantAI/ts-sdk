# %%
from testsavant.guard import InputGuard, OutputGuard
from testsavant.guard.output_scanners import LanguageSame
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
def dummy_llm(input):
    return input
long_article = "Once upon a time, in a land far, far away, there lived a wise old owl. The owl was known throughout the land for its wisdom and knowledge. Every day, animals from all over the forest would come to the owl to seek advice and guidance. The owl would listen patiently to their problems and offer thoughtful solutions. One day, a young rabbit came to the owl with a big problem. The rabbit had lost its way in the forest and couldn't find its way back home. The owl listened carefully and then said, 'Don't worry, little one. I will help you find your way back home.' The owl then flew high into the sky and looked around the forest. After a few moments, it spotted the rabbit's home in the distance. The owl flew back down to the rabbit and said, 'Follow me, and I will lead you back home.' The rabbit followed the owl through the forest, and soon enough, they arrived at the rabbit's home. The rabbit was so grateful to the owl for helping it find its way back home. From that day on, the rabbit and the owl became good friends, and they would often go on adventures together in the forest. And so, the wise old owl continued to help animals from all over the land, sharing its wisdom and knowledge with anyone who needed it."
print(len(long_article))

ts_api = OutputGuard(
    API_KEY=os.environ.get("TEST_SAVANT_API_KEY"),
    PROJECT_ID=os.environ.get("TEST_SAVANT_PROJECT_ID"),
    remote_addr=os.environ.get("TEST_SAVANT_REMOTE_ADDR")
)
scanner = LanguageSame(tag="base", threshold=0.5)
ts_api.add_scanner(scanner)
# Out:
# 1223

# %%
prompt = "como estas? quiero hablar de algo que me molesta mucho, la gente que no respeta a los demás."
prompts = [prompt, prompt + " " + long_article, long_article + " " + prompt]

for prompt in prompts[:1]:
    result = ts_api.scan(prompt, long_article)
    if result.is_valid:
        print("Prompt is valid")
    else:
        print("Prompt is invalid")

for prompt in prompts[:1]:
    result = ts_api.scan(prompt, prompt)
    if result.is_valid:
        print("Prompt is valid")
    else:
        print("Prompt is invalid")
# Out:
# Prompt is invalid
# Prompt is valid
