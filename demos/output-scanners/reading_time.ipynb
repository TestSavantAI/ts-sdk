# %%
from testsavant.guard import InputGuard, OutputGuard
from testsavant.guard.output_scanners import ReadingTime
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
guard = OutputGuard()
read_scanner = ReadingTime(
    tag="default",
    truncate=True,
    max_time=1000
    )
guard.add_scanner(read_scanner)

# %%
correct_json = "once up on a time, " * 1000

guard.scan(None, correct_json).is_valid
# Out:
# True
