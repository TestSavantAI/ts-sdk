# %%
from testsavant.guard import InputGuard, OutputGuard
from testsavant.guard.output_scanners import URLReachability
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
guard = OutputGuard()
read_scanner = URLReachability(
    tag="default",
    repair=True
    )
guard.add_scanner(read_scanner)

# %%
correct_json = "google.com"

guard.scan(None, correct_json).is_valid
# Out:
# True
