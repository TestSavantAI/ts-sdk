# %%
from testsavant.guard import InputGuard, OutputGuard
from testsavant.guard.input_scanners import InvisibleText
import os
from dotenv import load_dotenv
load_dotenv()

# %%
text = "Once upon a time, there were people"
invisible_text = "\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b"

# %%
guard = InputGuard()
invisible_text_scanner = InvisibleText(tag="default")
guard.add_scanner(invisible_text_scanner)

# %%
for text in [text, invisible_text, text + invisible_text]:
    result = guard.scan(text)
    if result.is_valid:
        print("LLM api called")
    else:
        print("User request blocked")
